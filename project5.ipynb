# %%
#Import all relevant libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore
 
## This statement allows the visuals to render within your Jupyter Notebook.
# %matplotlib inline

# %%
filename = r"dataset.csv"
df = pd.read_csv(filename)

# %% [markdown]
# ### Viewing the dataframe

# %%
df.head()
# Out:
#                              title                   brand  \
# 0                        Yes or No            هاربر كولينز
# 1  Words to Inspire You Every Day!  The Happy Book Company
# 2                   Believe In You  The Happy Book Company
# 3                         Is it Me   دار علبز النشر العربي
# 4                       The Secret            سيمون وشوستر
#
#                            author               cover publication_date  \
# 0               ‎Spencer Johnson‎           Paperback             1993
# 1  ‎Staffs of Happy Book Company‎  Spiral Bound Cover             2024
# 2  ‎Staffs of Happy Book Company‎  Spiral Bound Cover             2024
# 3             ‎Lara Majdi Samhan‎           Paperback             2022
# 4                  ‎Rhonda Byrne‎           Hardcover             2006
#
#       category    reviews     num_pages price  \
# 0  تطوير الذات  Not found  ‎112‎ Pages‎    79
# 1  تطوير الذات  Not found  ‎365‎ Pages‎    69
# 2  تطوير الذات  Not found  ‎365‎ Pages‎    69
# 3  تطوير الذات         17  ‎155‎ Pages‎    35
# 4  تطوير الذات          4     ‎صفحة208‎   115
#
#                                              img_url Language  url
# 0  https://www.jarir.com/cdn-cgi/image/fit=contai...  انجليزي  NaN
# 1  https://www.jarir.com/cdn-cgi/image/fit=contai...  انجليزي  NaN
# 2  https://www.jarir.com/cdn-cgi/image/fit=contai...  انجليزي  NaN
# 3  https://www.jarir.com/cdn-cgi/image/fit=contai...  انجليزي  NaN
# 4  https://www.jarir.com/cdn-cgi/image/fit=contai...  انجليزي  NaN

# %%
df = df[df["publication_date"]!= "Not found"]

# %%
df.shape
# Out:
# (3375, 6)

# %%
df.groupby(by="category").mean()
# Out:
# C:\Users\mmm19\AppData\Local\Temp\ipykernel_33012\1923606959.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   df.groupby(by="category").mean()
#                                                     publication_date
# category
# إصدارات مكتبة جرير,  التاريخ والجغرافيا,  وصل ح...      2.024000e+03
# إصدارات مكتبة جرير,  التاريخ والجغرافيا,  وصل ح...      2.024000e+03
# إصدارات مكتبة جرير,  العلوم الاجتماعية والسياسية        1.011101e+07
# الأدب والشعر,  الخيال العلمي                           3.313444e+241
# الأدب والشعر,  الخيال العلمي,                          3.305249e+241
# ...                                                              ...
# وصل حديثاً,  القانون,                                   2.246891e+34
# وصل حديثاً,  القانون,  الأفضل مبيعاً                    6.694003e+10
# وصل حديثاً,  القصة والرواية                             3.365337e+22
# وصل حديثاً,  القصة والرواية,                            8.796531e+89
# وصل حديثاً,  القصة والرواية,  الأدب والشعر              2.024000e+03
#
# [86 rows x 1 columns]

# %%
df[df["num_pages"]== "Not found"]
# Out:
#                       cover publication_date  \
# 40                Paperback             2016
# 52    Mass Market Paperback             2016
# 80                Paperback             2015
# 88                Paperback             2017
# 91                Paperback             2017
# ...                     ...              ...
# 3495              Paperback             2003
# 3547              غلاف ورقي             2020
# 3550          غلاف مقوى فني             2015
# 3645              غلاف ورقي             2023
# 3652              غلاف ورقي             2023
#
#                               category  num_pages price Language
# 40                         تطوير الذات  Not found    25  انجليزي
# 52                         تطوير الذات  Not found    59  انجليزي
# 80                         تطوير الذات  Not found    19  انجليزي
# 88                         تطوير الذات  Not found    46  انجليزي
# 91                         تطوير الذات  Not found    50  انجليزي
# ...                                ...        ...   ...      ...
# 3495                     الكتب الطبية,  Not found    35  انجليزي
# 3547  وصل حديثاً,  التاريخ والجغرافيا,  Not found    34     عربي
# 3550               التاريخ والجغرافيا,  Not found   425     عربي
# 3645   التاريخ والجغرافيا,  وصل حديثاً  Not found    65     عربي
# 3652   التاريخ والجغرافيا,  وصل حديثاً  Not found    74     عربي
#
# [226 rows x 6 columns]

# %%
df.drop(columns=["brand", "author", "reviews", "url"], inplace=True)

# %%
Titles = df["title"]
df.drop(columns=["title"], inplace=True)

# %%
img_urls = df["img_url"]
df.drop(columns=["img_url"], inplace=True)
